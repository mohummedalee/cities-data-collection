# %%
### single-constraint across LLM split by domains

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates
import seaborn as sns


prefix = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/'
prefix2 = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/figures/'

parallel = pd.read_csv(prefix+'code/rq2_2/parallel_df_llm_sg_.csv')
parallel = parallel.drop(['state', 'Unnamed: 0'], axis=1)

parallel
# Out:
#           domain     model  age  financial  family_structure  gender  race  \
# 0   openBusiness   mistral    3          3                 3       0     0
# 1   openBusiness   llama31    3          3                 3       1     0
# 2   openBusiness     gpt4o    3          3                 3       2     0
# 3   openBusiness  claude35    3          3                 3       2     0
# 4   openBusiness     gpt35    3          3                 3       3     0
# ..           ...       ...  ...        ...               ...     ...   ...
# 67  openBusiness   llama31    3          3                 3       0     3
# 68  openBusiness     gpt4o    3          3                 3       0     3
# 69  openBusiness  claude35    3          3                 3       0     3
# 70  openBusiness     gpt35    3          3                 3       0     3
# 71  openBusiness     gemma    3          3                 3       0     3
#
#     health  education  geographic
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

attributes = ['financial', 'family_structure', 'age',\
               'gender', 'race', 'health', 'education', 'geographic']

df = parallel

# Define the color palette (one color per category across all domains)
colors = sns.color_palette("Set2", n_colors=len(df.index))
colors = sns.set_palette("colorblind")

# Create a subplot figure with a bar plot in each column
fig, axes = plt.subplots(4, 2, figsize=(10, 20), sharey=False)
#fig, axes = plt.subplots(2, 4, figsize=(20, 10), sharey=False)

# Flatten the axes array for easy iteration
axes = axes.flatten()
# Loop through each domain (column) to create a bar plot
for i, (col, ax) in enumerate(zip(attributes, axes)):

    #sns.barplot(x=df.index, y=df[col], hue=df['condition'], ax=ax, palette=colors, edgecolor="black")
    sns.barplot(x=df['domain'], y=df[col], hue=df['model'], ax=ax, palette=colors, edgecolor="black")
    ax.set_title(col,fontsize=30)
    ax.set_xlabel('')
    ax.set_ylabel("significance levels", fontsize=20)
    #ax.set_xticklabels(rotation=45)
    ax.set_xticklabels(['tourism', 'relocation', 'openBusiness'], rotation=45, fontsize=20)
    #ax.set_xticklabels(['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma'], rotation=45, fontsize=20)
    ax.set_yticklabels(['', '', '*', '', '**', '', '***'],fontsize=30)
    ax.set_ylim([0,3.2])
    hatches = ['-', '+', 'x', '\\', '*', 'o']
    hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*','..', '**']
    ## Loop over the bars
    #for bars, hatch in zip(ax.containers, hatches):
    # Set a different hatch for each group of bars
    #    for bar in bars:
    #        bar.set_hatch(hatch)
    #ax.set_xlabel(fontsize=30)
   # ax.tick_params(labelsize=5)
    if col != 'geographic':
        ax.get_legend().set_visible(False)
plt.tight_layout()
plt.savefig(prefix2+"rq2_2_dem_domain_sg.pdf", format='pdf', dpi=300)

plt.show()
# Out:
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/3015620452.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['tourism', 'relocation', 'openBusiness'], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/3015620452.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['', '', '*', '', '**', '', '***'],fontsize=30)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/3015620452.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['tourism', 'relocation', 'openBusiness'], rotation=45, fontsize=20)
# ...

# %%
### generic and single-constraint across LLM

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates
import seaborn as sns


prefix = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/'
prefix2 = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/figures/'

parallel1 = pd.read_csv(prefix+'code/rq2_2/parallel_df_llm_gn_.csv')

r, c = parallel1.shape
parallel1['condition']=r*['generic']

parallel2 = pd.read_csv(prefix+'code/rq2_2/parallel_df_llm_sg_.csv')
r, c = parallel2.shape
parallel2['condition']=r*['single_constraint']

parallel = pd.concat([parallel1, parallel2], axis=0)
parallel = parallel.drop(['state', 'Unnamed: 0'], axis=1)
parallel
# Out:
#           domain     model  age  financial  family_structure  gender  race  \
# 0   openBusiness   mistral    3          3                 3       0     0
# 1   openBusiness   llama31    3          3                 3       1     0
# 2   openBusiness     gpt4o    3          3                 3       2     0
# 3   openBusiness  claude35    3          3                 3       2     0
# 4   openBusiness     gpt35    3          3                 3       3     0
# ..           ...       ...  ...        ...               ...     ...   ...
# 67  openBusiness   llama31    3          3                 3       0     3
# 68  openBusiness     gpt4o    3          3                 3       0     3
# 69  openBusiness  claude35    3          3                 3       0     3
# 70  openBusiness     gpt35    3          3                 3       0     3
# 71  openBusiness     gemma    3          3                 3       0     3
#
#     health  education  geographic          condition
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

attributes = ['financial', 'family_structure', 'age',\
               'gender', 'race', 'health', 'education', 'geographic']

df = parallel

# Define the color palette (one color per category across all domains)
colors = sns.color_palette("Set2", n_colors=len(df.index))

# Create a subplot figure with a bar plot in each column
#fig, axes = plt.subplots(4, 2, figsize=(10, 20), sharey=False)
fig, axes = plt.subplots(2, 4, figsize=(20, 10), sharey=False)

# Flatten the axes array for easy iteration
axes = axes.flatten()
# Loop through each domain (column) to create a bar plot
for i, (col, ax) in enumerate(zip(attributes, axes)):
    #sns.barplot(x=df.index, y=df[col], hue=df['condition'], ax=ax, palette=colors, edgecolor="black")
    #sns.barplot(x=df['model'], y=df[col], hue=df['condition'], ax=ax, palette=colors, edgecolor="black")
    sns.barplot(x=df['model'], y=df[col], ax=ax, color='#E74C3C', edgecolor="black")
    ax.set_title(col,fontsize=30)
    ax.set_xlabel('')
    ax.set_ylabel("significance levels", fontsize=20)
    #ax.set_xticklabels(rotation=45)
    #ax.set_xticklabels(['tourism', 'relocation', 'openBusiness'], rotation=45, fontsize=20)
    ax.set_xticklabels(['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma'], rotation=45, fontsize=20)
    ax.set_yticklabels(['', '', '*', '', '**', '', '***'],fontsize=30)
    ax.set_ylim([0,3.2])
    hatches = ['-', '+', 'x', '\\', '*', 'o']
    hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*','..', '**']
    ## Loop over the bars
    hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*']  # List of hatch patterns
    for i, bar in enumerate(ax.patches):
        bar.set_hatch(hatches[i % len(hatches)])  # Cycle through hatch patterns

    #for bars, hatch in zip(ax.containers, hatches):
    # Set a different hatch for each group of bars
     #   for bar in bars:
      #      bar.set_hatch(hatch)
    #ax.set_xlabel(fontsize=30)
   # ax.tick_params(labelsize=5)
plt.tight_layout()
plt.savefig(prefix2+"rq2_2_dem_sg.pdf", format='pdf', dpi=300)

plt.show()
# Out:
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_3114/1931756825.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma'], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_3114/1931756825.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['', '', '*', '', '**', '', '***'],fontsize=30)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_3114/1931756825.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma'], rotation=45, fontsize=20)
# ...

# %%
### generic and single-constraint across LLM 
### -- under-representation and over-representation

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates
import seaborn as sns


prefix = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/'
prefix2 = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/figures/'

#parallel1 = pd.read_csv(prefix+'code/rq2_2/parallel_df_llm_gn_sensitive.csv')

#r, c = parallel1.shape
#parallel1['condition']=r*['generic']

parallel = pd.read_csv(prefix+'code/rq2_2/parallel_df_llm_sg_sensitive.csv')
parallel = parallel.drop(['state', 'domain', 'Unnamed: 0'], axis=1)

#r, c = parallel2.shape
#parallel2['condition']=r*['single_constraint']

#parallel = pd.concat([parallel1, parallel2], axis=0)
#parallel = parallel.drop(['state', 'domain', 'Unnamed: 0'], axis=1)
#parallel
parallel
# Out:
#         model  age  race  family_structure family_structure_type age_type  \
# 0     mistral    0     0                 3                larger   larger
# 1     mistral    3     0                 1               smaller  smaller
# 2     llama31    0     0                 3                larger   larger
# 3     llama31    3     0                 3               smaller  smaller
# 4       gpt4o    0     0                 3                larger   larger
# ..        ...  ...   ...               ...                   ...      ...
# 139  claude35    3     3                 3               smaller  smaller
# 140     gpt35    0     3                 1                larger   larger
# 141     gpt35    3     3                 3               smaller  smaller
# 142     gemma    0     3                 0                larger   larger
# 143     gemma    3     3                 3               smaller  smaller
#
#     race_type
# 0      larger
# 1     smaller
# 2      larger
# 3     smaller
# ...

# %%
#parallel1 = parallel[parallel['family_structure_type']=='larger']
#parallel2 = parallel[parallel['family_structure_type']=='smaller']
# just single constraint
parallel1 = parallel[parallel['family_structure_type']=='larger']
parallel2 = parallel[parallel['family_structure_type']=='smaller']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

situation = 'smaller'
#situation = 'larger'
if situation == 'smaller':
    df = parallel2
else:
    df = parallel1

# Define the color palette (one color per category across all domains)
colors = sns.color_palette("Set2", n_colors=len(df.index))

# Create a subplot figure with a bar plot in each column
#fig, axes = plt.subplots(4, 2, figsize=(10, 20), sharey=False)
fig, axes = plt.subplots(1, 3, figsize=(20, 5), sharey=False)

# Flatten the axes array for easy iteration
axes = axes.flatten()
# Loop through each domain (column) to create a bar plot
for i, (col, ax) in enumerate(zip(['age', 'race', 'family_structure'], axes)):
    if situation == 'smaller':
        sns.barplot(df, x='model', y=col, ax=ax, color="#1ABC9C", edgecolor="black")
    else:
        sns.barplot(df, x='model', y=col, ax=ax, color="#F1C40F", edgecolor="black")

    #sns.barplot(df, x='model', y=col, hue='condition', ax=ax, palette=colors, edgecolor="black")
    ax.set_title(col,fontsize=30)
    ax.set_xlabel('')
    ax.set_ylabel("significance levels", fontsize=20)
    #ax.set_xticklabels(rotation=45)
    #ax.set_xticklabels(['tourism', 'relocation', 'openBusiness'], rotation=45, fontsize=20)
    ax.set_xticklabels(['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma'], rotation=45, fontsize=20)
    ax.set_yticklabels(['', '', '*', '', '**', '', '***'],fontsize=30)
    ax.set_ylim([0,3.2])
    #ax.set_xlabel(fontsize=30)
    #ax.tick_params(labelsize=5)
    
    hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*','..', '**']
    # Loop over the bars
    #print('hi')
    hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*']  # List of hatch patterns
    for i, bar in enumerate(ax.patches):
        bar.set_hatch(hatches[i % len(hatches)])  # Cycle through hatch patterns
    #for bars, hatch in zip(ax.containers, hatches):
    # Set a different hatch for each group of bars
     #   for bar in bars:
      #      bar.set_hatch(hatch)
    #ax.set_xlabel(fontsize=30)
    #ax.tick_params(labelsize=5)
plt.tight_layout()
if situation == 'smaller':
    plt.savefig(prefix2+"rq2_2_dem_sg_smaller.pdf", format='pdf', dpi=300)
else:
    plt.savefig(prefix2+"rq2_2_dem_sg_larger.pdf", format='pdf', dpi=300)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/3455768852.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma'], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/3455768852.py:35: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['', '', '*', '', '**', '', '***'],fontsize=30)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/3455768852.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma'], rotation=45, fontsize=20)
# ...

# %% [markdown]
# ### single-constraint demographic attributes of each class
# ### across LLM where the same class contained both
# ### under-representated and over-representated attributes

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import pickle

race_d = defaultdict(lambda: defaultdict(int))
age_d = defaultdict(lambda: defaultdict(int))
fam_d = defaultdict(lambda: defaultdict(int))
gender_d = defaultdict(lambda: defaultdict(int))
health_d = defaultdict(lambda: defaultdict(int))




print(race_d)
prefix = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/rq2_2/dicts/'
prefix2 = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/figures/'

states = ['Kansas', 'Florida', 'Ohio', 'Michigan', 'Oregon', \
          'Wyoming', 'Alabama', 'Tennessee', 'Arkansas', 'New Jersey',\
             'Maryland', 'Massachusetts']
models = ['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma']
mode = 'sg'
ages = ['age_median', 'age_over_65', 'age_over_80', 'age_under_10', 'age_10_to_19',]
races = ['race_black', 'race_asian', 'race_native', 'hispanic', 'race_pacific']
family_structure = ['family_size', 'divorced', 'never_married',]
gender = ['female']
health = ['disabled']


for model in models:
    for state in states:
        with open(prefix+state+'_'+model+'_'+mode+'.pkl', 'rb') as f:
            loaded_dict = pickle.load(f)
            #print(loaded_dict)
            for race in races:
                for one in loaded_dict[race]:
                    if one:
                        race_d[model][race]+=1
            for age in ages:
                for one in loaded_dict[age]:
                    if one:
                        age_d[model][age]+=1
            for family in family_structure:
                for one in loaded_dict[family]:
                    if one:
                        fam_d[model][family]+=1
            for gen in gender:
                for one in loaded_dict[gen]:
                    if one:
                        gender_d[model][gen]+=1
            for abl in health:
                for one in loaded_dict[abl]:
                    if one:
                        health_d[model][abl]+=1

gender_d
# Out:
# defaultdict(<function <lambda> at 0x14f0d07c0>, {})
# defaultdict(<function __main__.<lambda>()>,
#             {'mistral': defaultdict(int, {'female': 2}),
#              'llama31': defaultdict(int, {'female': 3}),
#              'gpt4o': defaultdict(int, {'female': 3}),
#              'claude35': defaultdict(int, {'female': 4}),
#              'gpt35': defaultdict(int, {'female': 3}),
#              'gemma': defaultdict(int, {'female': 3})})

# %%
import pandas as pd
df = pd.DataFrame(columns=['race_type', 'model', 'race', 'age_type', 'age',\
                            'family', 'family_type'])
race_type = ['race_black', 'race_native', 'hispanic', 'race_pacific', 'race_asian']
age_type = ['age_median', 'age_over_65', 'age_over_80', 'age_under_10', 'age_10_to_19']
family_type = ['family_size', 'divorced', 'never_married']
gender_type = ['female']
health_type = ['disabled']


models = ['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma']

r_data = {
        'mistral': [1, 4, 2, 3, 0],
        'llama31': [1, 4, 2, 5, 0],
        'gpt4o': [1, 4, 2, 6, 0],
        'claude35': [1, 4, 2, 6, 0],
        'gpt35': [1,4, 2, 6, 0],
        'gemma': [1,3, 2, 5, 0],
       }
a_data = {
        'mistral': [8, 6, 5, 3, 1],
        'llama31': [8, 7, 5, 3, 2],
        'gpt4o': [8, 7, 5, 4, 1],
        'claude35': [8, 7, 5, 4, 1],
        'gpt35': [8,7,5, 4, 1],
        'gemma': [8,8, 5, 4, 1],
       }

f_data = {
        'mistral': [6, 4, 0],
        'llama31': [6, 6, 0],
        'gpt4o': [7, 7, 0],
        'claude35': [6, 8, 0],
        'gpt35': [7, 6, 0],
        'gemma': [8, 6, 0],
       }

gen_data = {
        'mistral': [2],
        'llama31': [3],
        'gpt4o': [3],
        'claude35': [4],
        'gpt35': [3],
        'gemma': [3],
       }

dis_data = {
        'mistral': [10],
        'llama31': [11],
        'gpt4o': [11],
        'claude35': [11],
        'gpt35': [11],
        'gemma': [11],
       }

for j, rtype in enumerate(race_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'race'] = r_data[model][j]
        df.loc[j*len(models)+p, 'race_type'] = rtype

for j, atype in enumerate(age_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'age'] = a_data[model][j]
        df.loc[j*len(models)+p, 'age_type'] = atype

for j, ftype in enumerate(family_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'family'] = f_data[model][j]
        df.loc[j*len(models)+p, 'family_type'] = ftype

for j, ftype in enumerate(gender_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'gender'] = gen_data[model][j]
        df.loc[j*len(models)+p, 'gender_type'] = ftype

for j, ftype in enumerate(health_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'health'] = dis_data[model][j]
        df.loc[j*len(models)+p, 'health_type'] = ftype

df
# Out:
#        race_type     model race      age_type age family    family_type  \
# 0     race_black   mistral    1    age_median   8      6    family_size
# 1     race_black   llama31    1    age_median   8      6    family_size
# 2     race_black     gpt4o    1    age_median   8      7    family_size
# 3     race_black  claude35    1    age_median   8      6    family_size
# 4     race_black     gpt35    1    age_median   8      7    family_size
# 5     race_black     gemma    1    age_median   8      8    family_size
# 6    race_native   mistral    4   age_over_65   6      4       divorced
# 7    race_native   llama31    4   age_over_65   7      6       divorced
# 8    race_native     gpt4o    4   age_over_65   7      7       divorced
# 9    race_native  claude35    4   age_over_65   7      8       divorced
# 10   race_native     gpt35    4   age_over_65   7      6       divorced
# 11   race_native     gemma    3   age_over_65   8      6       divorced
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.ticker as ticker

# Example data: columns representing domains and values for each category within each domain

d_att = {
0:  ['age_median', 'age_over_65', 'age_over_80', 'age_under_10', 'age_10_to_19'],
1: ['race_black', 'race_native', 'hispanic', 'race_pacific', 'race_asian'],
2: ['family_size', 'divorced', 'never_married'],
3: ['female'],
4: ['disabled']
}

# Define the color palette (one color per category across all domains)
colors = sns.color_palette("Set2", n_colors=len(df.index))
colors = sns.set_palette("colorblind")

# Create a subplot figure with a bar plot in each column
fig, axes = plt.subplots(2, 3, figsize=(20, 10), sharey=False)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Loop through each domain (column) to create a bar plot
for i, (att, ax) in enumerate(zip(['age', 'race', 'family', 'gender', 'health'], axes)):

    #sns.barplot(df, x=att+'_type', y=att, hue='model', ax=ax, palette=colors, edgecolor="black")
    sns.barplot(df, x=att+'_type', y=att, hue='model', ax=ax, palette=colors, edgecolor="black")
    ax.set_title(att,fontsize=30)
    ax.set_xlabel('')
    ax.set_ylabel("counts", fontsize=20)
    ax.set_xticklabels(d_att[i], rotation=45, fontsize=20)
    ax.set_ylim([0,12])
    if att == 'gender' or att == 'health' or att == 'family':
        ax.set_xlim([-1,5])
        
    #ax.set_xlim([-2,6])
    #hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*','..', '**']
    # Loop over the bars
    #for bars, hatch in zip(ax.containers, hatches):
    # Set a different hatch for each group of bars
     #   for bar in bars:
      #      bar.set_hatch(hatch)
    if att != 'race':
        ax.get_legend().set_visible(False)
fig.delaxes(axes.flat[5])
plt.tight_layout()
plt.savefig(prefix2+"rq2_2_dem_sg_att_smaller.pdf", format='pdf', dpi=300)


plt.tight_layout()
plt.show()
# Out:
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_3114/3951934408.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[i], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_3114/3951934408.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[i], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_3114/3951934408.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[i], rotation=45, fontsize=20)
# ...

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import pickle


fam_d = defaultdict(lambda: defaultdict(int))
fin_d = defaultdict(lambda: defaultdict(int))
race_d = defaultdict(lambda: defaultdict(int))
geo_d = defaultdict(lambda: defaultdict(int))
edu_d = defaultdict(lambda: defaultdict(int))
age_d = defaultdict(lambda: defaultdict(int))



prefix = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/rq2_2/dicts/'
prefix2 = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/figures/'

states = ['Kansas', 'Florida', 'Ohio', 'Michigan', 'Oregon', \
          'Wyoming', 'Alabama', 'Tennessee', 'Arkansas', 'New Jersey',\
             'Maryland', 'Massachusetts']
condition='sg'
models = ['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma']

mode = 'sg'


family_structure = ['age_median', 'family_size', 'never_married','married']
financial = ['income_household_median', 'home_value', 'rent_median',\
             'income_household_150_over', 'income_household_100_to_150']
races = ['race_white']
geographic = ['commute_time']
education = ['education_college_or_above']
ages = ['age_median']


for model in models:
    for state in states:
        with open(prefix+state+'_'+model+'_'+mode+'_large.pkl', 'rb') as f:
            loaded_dict = pickle.load(f)
            #print(loaded_dict)
            for family in family_structure:
                for one in loaded_dict[family]:
                    if one:
                        fam_d[model][family]+=1
            for fin in financial:
                for one in loaded_dict[fin]:
                    if one:
                        fin_d[model][fin]+=1
            for race in races:
                for one in loaded_dict[race]:
                    if one:
                        race_d[model][race]+=1
            for geo in geographic:
                for one in loaded_dict[geo]:
                    if one:
                        geo_d[model][geo]+=1
            for edu in education:
                for one in loaded_dict[edu]:
                    if one:
                        edu_d[model][edu]+=1
            for age in ages:
                for one in loaded_dict[age]:
                    if one:
                        age_d[model][age]+=1
geo_d
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'mistral': defaultdict(int, {'commute_time': 1}),
#              'llama31': defaultdict(int, {'commute_time': 1}),
#              'gpt4o': defaultdict(int, {'commute_time': 1}),
#              'claude35': defaultdict(int, {'commute_time': 1}),
#              'gpt35': defaultdict(int, {'commute_time': 1}),
#              'gemma': defaultdict(int, {'commute_time': 1})})

# %%
import pandas as pd
df = pd.DataFrame()
fin_type = ['home_value', 'rent_median', 'income_household_150_over',\
             'income_household_100_to_150', 'income_household_median']
family_type = ['age_median', 'family_size', 'never_married']
race_type = ['race_white']
geo_type = ['commute_time']
edu_type = ['education_college_or_above']
age_type = ['age_median']

models = ['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma']


f_data = {
        'mistral': [2, 2, 9],
        'llama31': [2, 2, 9],
        'gpt4o': [2, 2, 10],
        'claude35': [3, 2, 11],
        'gpt35': [2, 2, 10],
        'gemma': [0, 3, 10],
       }

fin_data = {
        'mistral': [7, 7, 8, 2, 2],
        'llama31': [9, 7, 9, 2, 5],
        'gpt4o': [10, 8, 9, 3, 5],
        'claude35': [10, 6, 9, 3, 5],
        'gpt35': [10, 6, 9, 3, 5],
        'gemma': [9, 6, 9, 3, 4],
       }

age_data = {
        'mistral': [2],
        'llama31': [2],
        'gpt4o': [2],
        'claude35': [3],
        'gpt35': [2],
        'gemma': [2],
       }

race_data = {
        'mistral': [2],
        'llama31': [2],
        'gpt4o': [3],
        'claude35': [3],
        'gpt35': [3],
        'gemma': [2],
       }

edu_data = {
        'mistral': [11],
        'llama31': [10],
        'gpt4o': [12],
        'claude35': [12],
        'gpt35': [12],
        'gemma': [11],
       }

geo_data = {
        'mistral': [1],
        'llama31': [1],
        'gpt4o': [1],
        'claude35': [1],
        'gpt35': [1],
        'gemma': [1],
       }

for j, ftype in enumerate(family_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'family'] = f_data[model][j]
        df.loc[j*len(models)+p, 'family_type'] = ftype

for j, ftype in enumerate(fin_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'financial'] = fin_data[model][j]
        df.loc[j*len(models)+p, 'financial_type'] = ftype


for j, ftype in enumerate(geo_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'geographic'] = geo_data[model][j]
        df.loc[j*len(models)+p, 'geographic_type'] = ftype

for j, ftype in enumerate(age_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'age'] = age_data[model][j]
        df.loc[j*len(models)+p, 'age_type'] = ftype

for j, ftype in enumerate(edu_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'education'] = edu_data[model][j]
        df.loc[j*len(models)+p, 'education_type'] = ftype

for j, ftype in enumerate(race_type):
    for p, model in enumerate(models):
        df.loc[j*len(models)+p, 'model'] = model
        df.loc[j*len(models)+p, 'race'] = race_data[model][j]
        df.loc[j*len(models)+p, 'race_type'] = ftype

df
# Out:
#        model  family    family_type  financial               financial_type
# 0    mistral     2.0     age_median        7.0                   home_value
# 1    llama31     2.0     age_median        9.0                   home_value
# 2      gpt4o     2.0     age_median       10.0                   home_value
# 3   claude35     3.0     age_median       10.0                   home_value
# 4      gpt35     2.0     age_median       10.0                   home_value
# 5      gemma     0.0     age_median        9.0                   home_value
# 6    mistral     2.0    family_size        7.0                  rent_median
# 7    llama31     2.0    family_size        7.0                  rent_median
# 8      gpt4o     2.0    family_size        8.0                  rent_median
# 9   claude35     2.0    family_size        6.0                  rent_median
# 10     gpt35     2.0    family_size        6.0                  rent_median
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Example data: columns representing domains and values for each category within each domain

d_att = {
    0: ['home_value', 'rent_median', 'income_household_150_over',\
             'income_household_100_to_150', 'income_household_median'],
1: ['age_median', 'family_size', 'never_married']
}

# Define the color palette (one color per category across all domains)
colors = sns.color_palette("Set2", n_colors=len(df.index))
colors = sns.set_palette("colorblind")

# Create a subplot figure with a bar plot in each column
fig, axes = plt.subplots(1, 2, figsize=(20, 10), sharey=False)

# Flatten the axes array for easy iteration
axes = axes.flatten()
# Loop through each domain (column) to create a bar plot
for i, (att, ax) in enumerate(zip(['financial','family'], axes)):

    sns.barplot(df, x=att+'_type', y=att, hue='model', ax=ax, palette=colors, edgecolor="black")
    ax.set_title(att,fontsize=30)
    ax.set_xlabel('')
    ax.set_ylabel("counts", fontsize=20)
    ax.set_xticklabels(d_att[i], rotation=45, fontsize=20)
    ax.set_ylim([0,12])
    hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*','..', '**']
    # Loop over the bars
    #for bars, hatch in zip(ax.containers, hatches):
    # Set a different hatch for each group of bars
     #   for bar in bars:
      #      bar.set_hatch(hatch)
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.4)
plt.savefig(prefix2+"rq2_2_dem_sg_att_larger.pdf", format='pdf', dpi=300)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/508155454.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[i], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/508155454.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[i], rotation=45, fontsize=20)

# %% [markdown]
# ### single-constraint across LLM
# ### -- under-representation and over-representation across domains

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates
import seaborn as sns


prefix = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/'
prefix2 = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/figures/'

parallel = pd.read_csv(prefix+'code/rq2_2/parallel_df_llm_sg_sensitive.csv')

parallel = parallel.drop(['state', 'Unnamed: 0'], axis=1)
parallel
# Out:
#            domain     model  age  race  family_structure  \
# 0    openBusiness   mistral    0     0                 3
# 1    openBusiness   mistral    3     0                 1
# 2    openBusiness   llama31    0     0                 3
# 3    openBusiness   llama31    3     0                 3
# 4    openBusiness     gpt4o    0     0                 3
# ..            ...       ...  ...   ...               ...
# 139  openBusiness  claude35    3     3                 3
# 140  openBusiness     gpt35    0     3                 1
# 141  openBusiness     gpt35    3     3                 3
# 142  openBusiness     gemma    0     3                 0
# 143  openBusiness     gemma    3     3                 3
#
#     family_structure_type age_type race_type
# 0                  larger   larger    larger
# 1                 smaller  smaller   smaller
# 2                  larger   larger    larger
# 3                 smaller  smaller   smaller
# 4                  larger   larger    larger
# ...

# %%
parallel1 = parallel[parallel['family_structure_type']=='larger']
parallel2 = parallel[parallel['family_structure_type']=='smaller']

parallel2
# Out:
#            domain     model  age  race  family_structure  \
# 1    openBusiness   mistral    3     0                 1
# 3    openBusiness   llama31    3     0                 3
# 5    openBusiness     gpt4o    3     0                 3
# 7    openBusiness  claude35    3     0                 3
# 9    openBusiness     gpt35    3     0                 3
# ..            ...       ...  ...   ...               ...
# 135  openBusiness   llama31    3     3                 3
# 137  openBusiness     gpt4o    3     3                 3
# 139  openBusiness  claude35    3     3                 3
# 141  openBusiness     gpt35    3     3                 3
# 143  openBusiness     gemma    3     3                 3
#
#     family_structure_type age_type race_type
# 1                 smaller  smaller   smaller
# 3                 smaller  smaller   smaller
# 5                 smaller  smaller   smaller
# 7                 smaller  smaller   smaller
# 9                 smaller  smaller   smaller
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

situation = 'smaller'
situation = 'larger'
if situation == 'smaller':
    df = parallel2
else:
    df = parallel1

# Define the color palette (one color per category across all domains)
colors = sns.color_palette("Set2", n_colors=len(df.index))

# Create a subplot figure with a bar plot in each column
#fig, axes = plt.subplots(4, 2, figsize=(10, 20), sharey=False)
fig, axes = plt.subplots(1, 3, figsize=(20, 5), sharey=False)

# Flatten the axes array for easy iteration
axes = axes.flatten()
# Loop through each domain (column) to create a bar plot
for i, (col, ax) in enumerate(zip(['age', 'race', 'family_structure'], axes)):
    sns.barplot(x=df['domain'], y=df[col], hue=df['model'], ax=ax, palette=colors, edgecolor="black")
    ax.set_title(col,fontsize=30)
    ax.set_xlabel('')
    ax.set_ylabel("significance levels", fontsize=20)
    #ax.set_xticklabels(rotation=45)
    ax.set_xticklabels(['tourism', 'relocation', 'openBusiness'], rotation=45, fontsize=20)
    #ax.set_xticklabels(['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma'], rotation=45, fontsize=20)
    ax.set_yticklabels(['', '', '*', '', '**', '', '***'],fontsize=30)
    ax.set_ylim([0,3.2])
    #ax.set_xlabel(fontsize=30)
    #ax.tick_params(labelsize=5)
    
    hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*','..', '**']
    # Loop over the bars
    print('hi')
    for bars, hatch in zip(ax.containers, hatches):
    # Set a different hatch for each group of bars
        for bar in bars:
            bar.set_hatch(hatch)
    #ax.set_xlabel(fontsize=30)
    #ax.tick_params(labelsize=5)
plt.tight_layout()
if situation == 'smaller':
    plt.savefig(prefix2+"rq2_2_dem_domain_sg_smaller.pdf", format='pdf', dpi=300)
else:
    plt.savefig(prefix2+"rq2_2_dem_domain_sg_larger.pdf", format='pdf', dpi=300)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/1149985058.py:23: UserWarning: The palette list has more values (72) than needed (6), which may not be intended.
#   sns.barplot(x=df['domain'], y=df[col], hue=df['model'], ax=ax, palette=colors, edgecolor="black")
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/1149985058.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['tourism', 'relocation', 'openBusiness'], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/1149985058.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['', '', '*', '', '**', '', '***'],fontsize=30)
# ...

# %%
### single-constraint across LLM per domain split by demographics attributes
### under and over represmtation of demographic attributes

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import pickle

race_d = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
age_d = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
fam_d = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))


domains = {'New Jersey': 'relocation', 'Florida': 'relocation',\
            'Ohio': 'relocation', 'Michigan': 'relocation', \
            'Oregon': 'openBusiness', 'Massachusetts': 'openBusiness',\
                'Maryland': 'openBusiness', 'Kansas' : 'openBusiness',\
                    'Wyoming': 'tourism', 'Arkansas' : 'tourism',\
                        'Alabama' : 'tourism', 'Tennessee' : 'tourism' }

prefix = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/rq2_2/dicts/'
prefix2 = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/figures/'

states = ['Kansas', 'Florida', 'Ohio', 'Michigan', 'Oregon', \
          'Wyoming', 'Alabama', 'Tennessee', 'Arkansas', 'New Jersey',\
             'Maryland', 'Massachusetts']
models = ['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma']
mode = 'sg'
ages = ['age_median', 'age_over_65', 'age_over_80', 'age_under_10', 'age_10_to_19',]
races = ['race_black', 'race_native', 'hispanic', 'race_pacific']
family_structure = ['family_size', 'divorced', 'never_married']

flag = 1

for model in models:
    for state in states:
        with open(prefix+state+'_'+model+'_'+mode+'.pkl', 'rb') as f:
            loaded_dict = pickle.load(f)
            #print(loaded_dict)
            for race in races:
                for one in loaded_dict[race]:
                    if one:
                        race_d[domains[state]][model][race]+=1
                        race_d[domains[state]][model]['race_asian']=0
                        if domains[state] == 'tourism' or domains[state] == 'relocation':
                            race_d[domains[state]][model]['hispanic']=0
                        if domains[state] == 'openBusiness' or domains[state] == 'relocation':
                            race_d[domains[state]][model]['black']=0
                        

            for age in ages:
                for one in loaded_dict[age]:
                    if one:
                        age_d[domains[state]][model][age]+=1
                    elif not age_d[domains[state]][model][age]:
                        age_d[domains[state]][model][age]=0
            for family in family_structure:
                for one in loaded_dict[family]:
                    if one:
                        fam_d[domains[state]][model][family]+=1
                        fam_d[domains[state]][model]['never_married']=0

# %%
# generate a dataframe
import pandas as pd
df_fam = pd.DataFrame()

for p, domain in enumerate(['tourism','relocation', 'openBusiness']):
    for m, model in enumerate(models):
        for t, att in enumerate(fam_d[domain][model]):
            df_fam.loc[p*len(models)*len(fam_d[domains[state]][model])+ m*len(fam_d[domains[state]][model])+t, 'model'] = model
            df_fam.loc[p*len(models)*len(fam_d[domains[state]][model])+ m*len(fam_d[domains[state]][model])+t, 'family'] = fam_d[domain][model][att]
            df_fam.loc[p*len(models)*len(fam_d[domains[state]][model])+ m*len(fam_d[domains[state]][model])+t, 'family_type'] = att
            df_fam.loc[p*len(models)*len(fam_d[domains[state]][model])+ m*len(fam_d[domains[state]][model])+t, 'domain'] = domain

df_fam
# Out:
#        model  family    family_type        domain
# 0    mistral     2.0    family_size       tourism
# 1    mistral     0.0  never_married       tourism
# 2    mistral     1.0       divorced       tourism
# 3    llama31     2.0    family_size       tourism
# 4    llama31     0.0  never_married       tourism
# 5    llama31     1.0       divorced       tourism
# 6      gpt4o     3.0    family_size       tourism
# 7      gpt4o     0.0  never_married       tourism
# 8      gpt4o     1.0       divorced       tourism
# 9   claude35     2.0    family_size       tourism
# 10  claude35     0.0  never_married       tourism
# 11  claude35     1.0       divorced       tourism
# 12     gpt35     3.0    family_size       tourism
# 13     gpt35     0.0  never_married       tourism
# 14     gpt35     1.0       divorced       tourism
# 15     gemma     4.0    family_size       tourism
# 16     gemma     0.0  never_married       tourism
# 17     gemma     1.0       divorced       tourism
# ...

# %%
df_race = pd.DataFrame()
i = 0
for p, domain in enumerate(['tourism','relocation', 'openBusiness']):
    for m, model in enumerate(models):
        for t, att in enumerate(race_d[domain][model]):

            df_race.loc[i, 'model'] = model
            df_race.loc[i, 'race'] = race_d[domain][model][att]
            df_race.loc[i, 'race_type'] = att
            df_race.loc[i, 'domain'] = domain
            i+=1

df_race
# Out:
#       model  race     race_type        domain
# 0   mistral   1.0   race_native       tourism
# 1   mistral   0.0    race_asian       tourism
# 2   mistral   0.0      hispanic       tourism
# 3   mistral   1.0  race_pacific       tourism
# 4   mistral   1.0    race_black       tourism
# ..      ...   ...           ...           ...
# 85    gemma   1.0   race_native  openBusiness
# 86    gemma   0.0    race_asian  openBusiness
# 87    gemma   0.0         black  openBusiness
# 88    gemma   2.0      hispanic  openBusiness
# 89    gemma   1.0  race_pacific  openBusiness
#
# [90 rows x 4 columns]

# %%
df_age = pd.DataFrame()
i= 0
for p, domain in enumerate(['tourism','relocation', 'openBusiness']):
    for m, model in enumerate(models):
        for t, att in enumerate(age_d[domain][model]):
            df_age.loc[i, 'model'] = model
            df_age.loc[i, 'age'] = age_d[domain][model][att]
            df_age.loc[i, 'age_type'] = att
            df_age.loc[i, 'domain'] = domain
            i+=1

df_age
# Out:
#       model  age      age_type        domain
# 0   mistral  3.0    age_median       tourism
# 1   mistral  3.0   age_over_65       tourism
# 2   mistral  1.0   age_over_80       tourism
# 3   mistral  0.0  age_under_10       tourism
# 4   mistral  0.0  age_10_to_19       tourism
# ..      ...  ...           ...           ...
# 85    gemma  2.0    age_median  openBusiness
# 86    gemma  2.0   age_over_65  openBusiness
# 87    gemma  2.0   age_over_80  openBusiness
# 88    gemma  3.0  age_under_10  openBusiness
# 89    gemma  0.0  age_10_to_19  openBusiness
#
# [90 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Example data: columns representing domains and values for each category within each domain

race_type = ['race_black', 'race_native', 'hispanic', 'race_pacific', 'race_asian']
age_type = ['age_median', 'age_over_65', 'age_over_80', 'age_under_10', 'age_10_to_19']


d_att = { 
0:  ['age_median', 'age_over_65', 'age_over_80', 'age_under_10', 'age_10_to_19'],
1: ['race_black', 'race_native', 'hispanic', 'race_pacific', 'race_asian'],
2: ['family_size', 'never_married', 'divorced']
}
# Define the color palette (one color per category across all domains)
colors = sns.color_palette("Set2", n_colors=len(df.index))
colors = sns.set_palette("colorblind")

# Create a subplot figure with a bar plot in each column
fig, axes = plt.subplots(3, 3, figsize=(20, 20), sharey=False)

# Flatten the axes array for easy iteration
axes = axes.flatten()
# Loop through each domain (column) to create a bar plot
for p, (domain, ax, att, df) in enumerate(zip(['tourism', 'tourism',\
                                                'tourism','relocation',\
                                                      'relocation', 'relocation',
                                                'openBusiness'\
                                                    , 'openBusiness', 'openBusiness'],\
                                              axes, \
                                              ['age', 'race', 'family']*3, \
                                                [df_age, df_race, df_fam]*3)):

    df = df[df['domain']==domain]
    #print(df)
    #print('')
    sns.barplot(df, x=att+'_type', y=att, hue='model', ax=ax, palette=colors,\
                 order=d_att[p%3], edgecolor="black")
    ax.set_title(att,fontsize=30)
    ax.set_xlabel('')
    ax.set_ylabel(domain, fontsize=30)
    ax.set_xticklabels(d_att[p%3], rotation=45, fontsize=20)
    ax.set_ylim([0,5])
    hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*','..', '**']
    # Loop over the bars
    #for bars, hatch in zip(ax.containers, hatches):
    # Set a different hatch for each group of bars
        #for bar in bars:
        #    bar.set_hatch(hatch)
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.4)
plt.tight_layout()
plt.savefig(prefix2+"rq2_2_dem_domain_sg_att_smaller.pdf", format='pdf', dpi=300)

plt.show()
# Out:
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/3863602665.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[p%3], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/3863602665.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[p%3], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/3863602665.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[p%3], rotation=45, fontsize=20)
# ...

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import pickle


fam_d = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
fin_d = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))


prefix = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/rq2_2/dicts/'
prefix2 = '/Users/shirandudy/Documents/Documents_new/NEU/projects/cities_representation/code/figures/'

states = ['Kansas', 'Florida', 'Ohio', 'Michigan', 'Oregon', \
          'Wyoming', 'Alabama', 'Tennessee', 'Arkansas', 'New Jersey',\
             'Maryland', 'Massachusetts']
domains = {'New Jersey': 'relocation', 'Florida': 'relocation',\
            'Ohio': 'relocation', 'Michigan': 'relocation', \
            'Oregon': 'openBusiness', 'Massachusetts': 'openBusiness',\
                'Maryland': 'openBusiness', 'Kansas' : 'openBusiness',\
                    'Wyoming': 'tourism', 'Arkansas' : 'tourism',\
                        'Alabama' : 'tourism', 'Tennessee' : 'tourism' }
condition='sg'
models = ['mistral', 'llama31', 'gpt4o', 'claude35', 'gpt35', 'gemma']

mode = 'sg'


family_structure = ['age_median', 'family_size', 'never_married','married']
financial = ['income_household_median', 'home_value', 'rent_median',\
             'income_household_150_over', 'income_household_100_to_150']

#family_structure = ['family_size', 'never_married','married']

for model in models:
    for state in states:
        with open(prefix+state+'_'+model+'_'+mode+'_large.pkl', 'rb') as f:
            loaded_dict = pickle.load(f)
            #print(loaded_dict)
            for family in family_structure:
                for one in loaded_dict[family]:
                    if one:
                        fam_d[domains[state]][model][family]+=1
            for fin in financial:
                for one in loaded_dict[fin]:
                    if one:
                        fin_d[domains[state]][model][fin]+=1
fin_d
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'openBusiness': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'mistral': defaultdict(int,
#                                       {'home_value': 3,
#                                        'rent_median': 3,
#                                        'income_household_150_over': 3,
#                                        'income_household_median': 1}),
#                           'llama31': defaultdict(int,
#                                       {'income_household_median': 2,
#                                        'home_value': 3,
#                                        'rent_median': 3,
#                                        'income_household_150_over': 3}),
#                           'gpt4o': defaultdict(int,
#                                       {'income_household_median': 2,
#                                        'home_value': 4,
# ...

# %%
# generate a dataframe
import pandas as pd
df_fam = pd.DataFrame()

i=0
for p, domain in enumerate(['tourism','relocation', 'openBusiness']):
    for m, model in enumerate(models):
        for t, att in enumerate(fam_d[domain][model]):
            df_fam.loc[i, 'model'] = model
            df_fam.loc[i, 'family'] = fam_d[domain][model][att]
            df_fam.loc[i, 'family_type'] = att
            df_fam.loc[i, 'domain'] = domain
            i+=1

df_fam
# Out:
#        model  family    family_type        domain
# 0    mistral     3.0  never_married       tourism
# 1    mistral     1.0     age_median       tourism
# 2    llama31     3.0  never_married       tourism
# 3      gpt4o     4.0  never_married       tourism
# 4   claude35     4.0  never_married       tourism
# 5   claude35     1.0     age_median       tourism
# 6      gpt35     3.0  never_married       tourism
# 7      gpt35     1.0     age_median       tourism
# 8      gemma     4.0  never_married       tourism
# 9    mistral     2.0    family_size    relocation
# 10   mistral     4.0  never_married    relocation
# 11   llama31     4.0  never_married    relocation
# 12   llama31     2.0    family_size    relocation
# 13   llama31     1.0     age_median    relocation
# 14     gpt4o     2.0    family_size    relocation
# 15     gpt4o     4.0  never_married    relocation
# 16     gpt4o     1.0     age_median    relocation
# 17  claude35     2.0    family_size    relocation
# ...

# %%
import pandas as pd
df_fin = pd.DataFrame()

i=0
for p, domain in enumerate(['tourism','relocation', 'openBusiness']):
    for m, model in enumerate(models):
        for t, att in enumerate(fin_d[domain][model]):
            df_fin.loc[i, 'model'] = model
            df_fin.loc[i, 'financial'] = fin_d[domain][model][att]
            df_fin.loc[i, 'financial_type'] = att
            df_fin.loc[i, 'domain'] = domain
            i+=1

df_fin
# Out:
#       model  financial               financial_type        domain
# 0   mistral        2.0                   home_value       tourism
# 1   mistral        2.0                  rent_median       tourism
# 2   mistral        2.0    income_household_150_over       tourism
# 3   mistral        1.0  income_household_100_to_150       tourism
# 4   llama31        3.0                   home_value       tourism
# ..      ...        ...                          ...           ...
# 73    gpt35        3.0    income_household_150_over  openBusiness
# 74    gemma        2.0      income_household_median  openBusiness
# 75    gemma        3.0                   home_value  openBusiness
# 76    gemma        3.0                  rent_median  openBusiness
# 77    gemma        3.0    income_household_150_over  openBusiness
#
# [78 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Example data: columns representing domains and values for each category within each domain

d_att = {
    0: ['income_household_median', 'home_value', 'rent_median',\
             'income_household_150_over', 'income_household_100_to_150'],
1: ['age_median', 'family_size', 'never_married','married']

}
# Define the color palette (one color per category across all domains)
colors = sns.color_palette("Set2", n_colors=len(df.index))
colors = sns.set_palette("colorblind")

# Create a subplot figure with a bar plot in each column
fig, axes = plt.subplots(3, 2, figsize=(20, 20), sharey=False)

# Flatten the axes array for easy iteration
axes = axes.flatten()
# Loop through each domain (column) to create a bar plot
for p, (domain, ax, att, df) in enumerate(zip(['tourism', 'tourism',\
                                               'relocation', 'relocation',\
                                                'openBusiness','openBusiness'],\
                                              axes, \
                                              ['financial', 'family']*3, \
                                                [df_fin, df_fam]*3)):

    df = df[df['domain']==domain]
    #print(df)
    #print('')
    sns.barplot(df, x=att+'_type', y=att, hue='model', ax=ax,\
                order=d_att[p%2], palette=colors, edgecolor="black")
    ax.set_title(att,fontsize=30)
    ax.set_xlabel('')
    ax.set_ylabel(domain, fontsize=30)
    ax.set_xticklabels(d_att[p%2], rotation=45, fontsize=20)
    #ax.set_ylim([0,5])
    hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*','..', '**']
    # Loop over the bars
    #for bars, hatch in zip(ax.containers, hatches):
    # Set a different hatch for each group of bars
    #    for bar in bars:
     #       bar.set_hatch(hatch)
    if domain != 'openBusiness':
      ax.get_legend().set_visible(False)
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.4)
plt.tight_layout()
plt.savefig(prefix2+"rq2_2_dem_domain_sg_att_larger.pdf", format='pdf', dpi=300)

plt.show()
# Out:
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/905016952.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[p%2], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/905016952.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[p%2], rotation=45, fontsize=20)
# /var/folders/g2/5xxky1ms39j84z1l3vcj2_3m0000gn/T/ipykernel_2784/905016952.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(d_att[p%2], rotation=45, fontsize=20)
# ...
